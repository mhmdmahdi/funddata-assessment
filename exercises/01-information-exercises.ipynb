# %%
# Make HTTP requests for internet reqources.
import urllib.request

# The URL of a text version of Alice in Wonderland.
book_url = 'https://www.gutenberg.org/files/11/11-0.txt'

# Get the book.
book = list(urllib.request.urlopen(book_url))

# Decode the lines and strip line endings.
book = [line.decode('utf-8-sig').strip() for line in book]

# Get a sample paragraph - I looked for this by hand.
paragraph = ' '.join(book[58:63])

# Show the paragraph.
print(paragraph)
# Out:
# Alice was beginning to get very tired of sitting by her sister on the bank, and of having nothing to do: once or twice she had peeped into the book her sister was reading, but it had no pictures or conversations in it, “and what is the use of a book,” thought Alice “without pictures or conversations?”

# %%
# Let's lower-case it.
alice = paragraph.lower()

# All letters and a space.
chars = 'abcdefghijklmnopqrstuvwxyz '

# And strip anything that is not a letter or space.
alice = ''.join([c for c in alice if c in chars])

# Show the paragraph now.
print(alice)
# Out:
# alice was beginning to get very tired of sitting by her sister on the bank and of having nothing to do once or twice she had peeped into the book her sister was reading but it had no pictures or conversations in it and what is the use of a book thought alice without pictures or conversations

# %%
# For doing (pseudo-)random things in Python.
import random

# Print a random character, for example.
print(random.choice(chars))
# Out:
# z

# %%
# Get the length of alice.
N = len(alice)
print(N)
# Generate N random characters from chars.
gener = random.choices(chars, k=N)

# Join them together in a string.
gener = ''.join(gener)

# Print.
print(gener)
# Out:
# 292
# fzbfyvcdccz m slcqumk cxyvh wrkjgbqbkcutapasvxsvbtptkwmmsokngslrtyzansg npdilyatltnua jgpjmbbexjlpcaouxc doclvsrpucmlobhhhy zrbtgmvhzseiznvguhpbvqgdyc nkbjzlucagcwaisjwyxxzmxyebftqzxfgld dairmtaytlrrowcivdwxppgifpzepreeqewfraccwtmzgwhpykktwrpmqgxcodoulguuldevoiywdnasvw tmqopqyzqqsxotpojq cou

# %%
# Get the whole book in one big string.
sbook = ''.join(book[26:]).lower()

# Create the weights - count the occurences of each character in the whole book.
weights = [sbook.count(c) for c in chars]

# Show the weights.
weights
# Out:
# [9801,
#  1743,
#  3008,
#  5455,
#  15402,
#  2374,
#  2938,
#  7902,
#  8611,
#  232,
#  1291,
#  5194,
#  2459,
#  8032,
#  9471,
#  1971,
#  223,
#  6617,
#  7246,
#  12225,
#  3970,
#  962,
#  2958,
#  181,
#  2592,
#  80,
#  26950]

# %%
# Generate a string using those weights.
wgenr = random.choices(chars, weights=weights, k=N)

# Join them together in a string.
wgenr = ''.join(wgenr)

# Print.
print(wgenr)
# Out:
# est tl e y denndungee  loythsgdgnaw nssh tnlrao encnyeg vhhaarerau y io l vss r wrt ny  iiihnee cos     sanwhuactne ateteteio  so eeosnaklikrorwt  snenciyehto n snyts sld yiwl   gyhs   tnmiln  etnattap ncdu stha e wnokeigm aad aeor dcdhn yga eeeetiyystr cyattdcha tbrhpvgiroe be  l gitaaoot n

# %%
# Create the weights.
twoghts = {c: {d: sbook.count(c + d) for d in chars} for c in chars}

# Show the weights.
twoghts
# Out:
# {'a': {'a': 0,
#   'b': 243,
#   'c': 208,
#   'd': 482,
#   'e': 1,
#   'f': 68,
#   'g': 220,
#   'h': 30,
#   'i': 752,
#   'j': 12,
#   'k': 131,
#   'l': 1018,
#   'm': 202,
#   'n': 1776,
#   'o': 3,
#   'p': 147,
#   'q': 0,
#   'r': 846,
#   's': 944,
#   't': 1345,
#   'u': 80,
#   'v': 178,
#   'w': 96,
#   'x': 12,
#   'y': 294,
#   'z': 5,
#   ' ': 660},
#  'b': {'a': 82,
#   'b': 68,
#   'c': 0,
#   'd': 1,
#   'e': 651,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 122,
#   'j': 8,
#   'k': 0,
#   'l': 124,
#   'm': 1,
#   'n': 0,
#   'o': 228,
#   'p': 0,
#   'q': 0,
#   'r': 62,
#   's': 35,
#   't': 13,
#   'u': 239,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 101,
#   'z': 0,
#   ' ': 3},
#  'c': {'a': 353,
#   'b': 0,
#   'c': 36,
#   'd': 0,
#   'e': 796,
#   'f': 0,
#   'g': 0,
#   'h': 517,
#   'i': 56,
#   'j': 0,
#   'k': 182,
#   'l': 87,
#   'm': 0,
#   'n': 0,
#   'o': 455,
#   'p': 0,
#   'q': 0,
#   'r': 125,
#   's': 1,
#   't': 236,
#   'u': 113,
# ...

# %%
# Loop through our character set.
for i in range(len(chars)):
    # Print the character and how many times it appears in Alice in Wonderland.
    print(f'{chars[i]}: {weights[i]}')
# Out:
# a: 9801
# b: 1743
# c: 3008
# d: 5455
# e: 15402
# f: 2374
# g: 2938
# h: 7902
# i: 8611
# j: 232
# k: 1291
# l: 5194
# m: 2459
# n: 8032
# o: 9471
# p: 1971
# q: 223
# r: 6617
# s: 7246
# t: 12225
# u: 3970
# v: 962
# w: 2958
# x: 181
# y: 2592
# z: 80
#  : 26950

# %%
# Start with space.
pairs = ' '

# Do the following N-1 times.
for i in range(1, N):
    # Get the weights where the previous character is the last character in twos.
    wt = twoghts[pairs[-1]]
    # Turn wt into a list, ordered by chars.
    wt = [wt[c] for c in chars]
    print(wt)
    # Randomly pick the next character using those weights.
    nextc = random.choices(chars, weights=wt, k=1)[0]
    # Append the character to twos.
    pairs = pairs + nextc
# Out:
# [3304, 909, 918, 843, 413, 784, 601, 1438, 1749, 107, 245, 738, 900, 533, 1533, 622, 171, 522, 2365, 4280, 293, 225, 1766, 6, 505, 2, 173]
# [116, 0, 3, 1, 179, 132, 1, 1, 190, 0, 0, 36, 2, 1, 423, 1, 0, 114, 3, 88, 126, 1, 0, 0, 7, 0, 831]
# [59, 53, 689, 730, 223, 193, 237, 1, 12, 0, 97, 345, 243, 2264, 299, 25, 0, 228, 715, 1492, 9, 105, 4, 11, 0, 27, 369]
# [353, 0, 36, 0, 796, 0, 0, 517, 56, 0, 182, 87, 0, 0, 455, 0, 0, 125, 1, 236, 113, 0, 0, 0, 8, 0, 35]
# [0, 243, 208, 482, 1, 68, 220, 30, 752, 12, 131, 1018, 202, 1776, 3, 147, 0, 846, 944, 1345, 80, 178, 96, 12, 294, 5, 660]
# [141, 99, 215, 1411, 597, 33, 1232, 8, 221, 3, 116, 100, 2, 57, 596, 7, 6, 3, 205, 577, 62, 22, 12, 17, 138, 0, 1460]
# [3304, 909, 918, 843, 413, 784, 601, 1438, 1749, 107, 245, 738, 900, 533, 1533, 622, 171, 522, 2365, 4280, 293, 225, 1766, 6, 505, 2, 173]
# [835, 55, 329, 1088, 553, 119, 145, 54, 112, 4, 19, 501, 324, 1147, 45, 188, 19, 2109, 722, 386, 8, 205, 79, 123, 224, 14, 4843]
# ...

# %%
pairs
# Out:
# ' fican es he ad l e he ack he wibe tho wid xpp s he t axcod d he gheemithes t gof oryomy y tt atecu shem ppllaryitore ce t mepe meynghare curyhet slly kemutali s goofosaigithe la ththe ait k wary cof othe lanin pridg opl ousay toweank h ioposhe g wewheveng ionerithe etathe war t s mmitr tcoc'

# %% [markdown]
# <h3 style="color: #001a79;">Exercise 1</h3>
#
# <hr style="border-top: 1px solid #001a79;" />
#
# <i h3 style="color: #001a79;">Remember to do these exercises in your own notebook in your assessment repository.</i>
#
# Adapt the code above to generate a 1000 character long string with weights based on the previous two characters.
#
# <hr style="border-top: 1px solid #001a79;" />

# %%
# Create the weights.
threeghts = {c: {d: {e: sbook.count(c + d + e) for e in chars} for d in chars} for c in chars}

# Show the weights.
threeghts

# This nested dict could be causing me more trouble but I may be in too deep to go back
# Currently have {c+ {d + e}} as my nested dicts I believe
# Would be better to have this as {c} + {d} + {e}
# Out:
# {'a': {'a': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'b': {'a': 0,
#    'b': 54,
#    'c': 0,
#    'd': 0,
#    'e': 7,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 7,
#    'j': 0,
#    'k': 0,
#    'l': 48,
#    'm': 0,
#    'n': 0,
#    'o': 106,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 3,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 15,
#    'z': 0,
#    ' ': 1},
#   'c': {'a': 0,
#    'b': 0,
#    'c': 28,
#    'd': 0,
#    'e': 48,
#    'f': 0,
#    'g': 0,
#    'h': 24,
#    'i': 2,
#    'j': 0,
#    'k': 48,
#    'l': 11,
#    'm': 0,
#    'n': 0,
#    'o': 4,
#    'p': 0,
#    'q': 0,
#    'r': 5,
#    's': 0,
#    't': 31,
# ...

# %%
# Start with space.
threes = ' '

# Do the following 1000 times.
for i in range(1):
    # Get the weights where the previous character is the last character in threes.
    wt2 = threeghts[threes[-1]]
    # Find the last character in 'threes'. Then go to my dictionary full of weights and pull out the weights
    # wt2 is now technically a dict
   # print(wt2)
    
    # Need to turn wt2 into a list, ordered by chars with just integers
#    wt2 = [wt2[c] for c in chars]
    resultList = list(wt2.values())
    # Method for converting a dict to list gotten from the below reference
    # https://www.tutorialspoint.com/How-to-convert-Python-Dictionary-to-a-list#:~:text=Create%20a%20variable%20to%20store,a%20list%20of%20an%20iteratable).
    
    #resultList2 = resultList.int()
    print(resultList)
    # This list is still a dict within a list. Need to extract the values from this list

    
    # Get the weights where the previous character is the last character in threes.
   # wts3 = threeghts[threes[-1]]
    # Turn wts2 into a list, ordered by chars.
   # wts3 = [wts3[c] for c in chars]
    
    # Randomly pick the next character using those weights.
#    nextc = random.choices(chars, weights=wt2, k=1)[0]
    # Append the character to twos.
    
    # Randomly pick the next character using those weights.
   # nexte = random.choices(chars, weights=wts3, k=1)[0]
    # Append the character to twos.
    
#    threes = threes + nextc
# Out:
# [{'a': 0, 'b': 100, 'c': 39, 'd': 54, 'e': 0, 'f': 57, 'g': 120, 'h': 5, 'i': 15, 'j': 0, 'k': 0, 'l': 567, 'm': 34, 'n': 1009, 'o': 0, 'p': 20, 'q': 0, 'r': 110, 's': 307, 't': 223, 'u': 3, 'v': 5, 'w': 30, 'x': 2, 'y': 0, 'z': 0, ' ': 600}, {'a': 76, 'b': 0, 'c': 0, 'd': 0, 'e': 449, 'f': 0, 'g': 0, 'h': 0, 'i': 42, 'j': 0, 'k': 0, 'l': 11, 'm': 0, 'n': 0, 'o': 64, 'p': 0, 'q': 0, 'r': 53, 's': 0, 't': 0, 'u': 138, 'v': 0, 'w': 0, 'x': 0, 'y': 76, 'z': 0, ' ': 0}, {'a': 274, 'b': 0, 'c': 0, 'd': 0, 'e': 20, 'f': 0, 'g': 0, 'h': 106, 'i': 6, 'j': 0, 'k': 0, 'l': 35, 'm': 0, 'n': 0, 'o': 338, 'p': 0, 'q': 0, 'r': 91, 's': 0, 't': 0, 'u': 48, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0, ' ': 0}, {'a': 68, 'b': 0, 'c': 0, 'd': 0, 'e': 101, 'f': 0, 'g': 0, 'h': 0, 'i': 179, 'j': 0, 'k': 0, 'l': 0, 'm': 0, 'n': 0, 'o': 393, 'p': 0, 'q': 0, 'r': 55, 's': 0, 't': 0, 'u': 46, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0, ' ': 0}, {'a': 63, 'b': 13, 'c': 0, 'd': 13, 'e': 2, 'f': 7, 'g': 6, 'h': 0, 'i':
# ...

# %%
threes
# Out:
# ' '

# %% [markdown]
# <h3 style="color: #001a79;">Exercise 2</h3>
#
# <hr style="border-top: 1px solid #001a79;" />
#
# <i h3 style="color: #001a79;">Remember to do these exercises in your own notebook in your assessment repository.</i>
#
# Explain why the log of zero is undefined.
#
# <hr style="border-top: 1px solid #001a79;" />

# %% [markdown]
# ## Why is the log of zero undefined?
#
# What is a logarithm and why is it useful for data science?
# Log scales are useful when trying to make sense of skewed data sets. An example of a log scale is the Richter scale. Log scales can help us visualise and interprate all of the data if say one data point has a much larger value than the rest therefore almost trivialising the smaller data points. But this is not a tru representation of whats really happening. It is just that a log scle is non-linear so we can get more 'value' out of the smaller data points.
# (https://www.dataclaritycorp.com/the-power-of-logarithmic-scale/)
#
# "The log is the exponent or power that a base must be raised to yield a given value" (Britannica definition https://www.britannica.com/science/logarithm)
#
# Going by this definition an understanding of the log is applied as follows:
# b^x = n
# x = logb n
#
# 2^3= 8
# 3 = log2 8
#
# Trying to apply this definition to log of 0:
# Logb0 = x
# 0 = b^x
# Unless b=0 we can never achieve the above result. Any values for x will not give an answer equal to 0.
# However b also cannot equal 0 as:
# x = logb n
# b=0
# x = log0n
# 0^x = n
# This definition will never give an answer to satisfy the above equations
